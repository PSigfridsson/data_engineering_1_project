# %%
from pyspark.sql import SparkSession

spark_session = SparkSession\
        .builder\
        .master("spark://192.168.2.181:7077") \
        .appName("weak_scaling_1_core")\
        .config("spark.dynamicAllocation.enabled", True)\
        .config("spark.shuffle.service.enabled", True)\
        .config("spark.cores.max", 1)\
        .getOrCreate()

spark_context = spark_session.sparkContext

df = spark_session.read\
    .option("header", "true")\
    .csv(['hdfs://192.168.2.181:9000/user/ubuntu/songs_collection/*'])

df = df.withColumn('Duration', df['Duration'].cast("float"))
df = df.filter(df['Duration'] >= 240)
print("Amount of songs longer than 240 sec: "+str(df.count()))

# Release cores and stop application.
spark_context.stop()

# %%
from pyspark.sql import SparkSession

spark_session = SparkSession\
        .builder\
        .master("spark://192.168.2.181:7077") \
        .appName("weak_scaling_2_core")\
        .config("spark.dynamicAllocation.enabled", True)\
        .config("spark.shuffle.service.enabled", True)\
        .config("spark.cores.max", 2)\
        .getOrCreate()

spark_context = spark_session.sparkContext

df = spark_session.read\
    .option("header", "true")\
    .csv(['hdfs://192.168.2.181:9000/user/ubuntu/songs_collection/*', 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection1/*'])

df = df.withColumn('Duration', df['Duration'].cast("float"))
df = df.filter(df['Duration'] >= 240)
print("Amount of songs longer than 240 sec: "+str(df.count()))

# Release cores and stop application.
spark_context.stop()

# %%
from pyspark.sql import SparkSession

spark_session = SparkSession\
        .builder\
        .master("spark://192.168.2.181:7077") \
        .appName("weak_scaling_3_core")\
        .config("spark.dynamicAllocation.enabled", True)\
        .config("spark.shuffle.service.enabled", True)\
        .config("spark.cores.max", 3)\
        .getOrCreate()

spark_context = spark_session.sparkContext

df = spark_session.read\
    .option("header", "true")\
    .csv(['hdfs://192.168.2.181:9000/user/ubuntu/songs_collection/*', 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection1/*', 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection2/*'])

df = df.withColumn('Duration', df['Duration'].cast("float"))
df = df.filter(df['Duration'] >= 240)
print("Amount of songs longer than 240 sec: "+str(df.count()))

# Release cores and stop application.
spark_context.stop()

# %%
from pyspark.sql import SparkSession

spark_session = SparkSession\
        .builder\
        .master("spark://192.168.2.181:7077") \
        .appName("weak_scaling_4_core")\
        .config("spark.dynamicAllocation.enabled", True)\
        .config("spark.shuffle.service.enabled", True)\
        .config("spark.cores.max", 4)\
        .getOrCreate()

spark_context = spark_session.sparkContext

df = spark_session.read\
    .option("header", "true")\
    .csv(['hdfs://192.168.2.181:9000/user/ubuntu/songs_collection/*', 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection1/*', 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection2/*'
          , 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection3/*'])

df = df.withColumn('Duration', df['Duration'].cast("float"))
df = df.filter(df['Duration'] >= 240)
print("Amount of songs longer than 240 sec: "+str(df.count()))

# Release cores and stop application.
spark_context.stop()

# %%
from pyspark.sql import SparkSession

spark_session = SparkSession\
        .builder\
        .master("spark://192.168.2.181:7077") \
        .appName("weak_scaling_5_core")\
        .config("spark.dynamicAllocation.enabled", True)\
        .config("spark.shuffle.service.enabled", True)\
        .config("spark.cores.max", 5)\
        .getOrCreate()

spark_context = spark_session.sparkContext

df = spark_session.read\
    .option("header", "true")\
    .csv(['hdfs://192.168.2.181:9000/user/ubuntu/songs_collection/*', 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection1/*', 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection2/*'
          , 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection3/*', 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection4/*'])

df = df.withColumn('Duration', df['Duration'].cast("float"))
df = df.filter(df['Duration'] >= 240)
print("Amount of songs longer than 240 sec: "+str(df.count()))

# Release cores and stop application.
spark_context.stop()

# %%
from pyspark.sql import SparkSession

spark_session = SparkSession\
        .builder\
        .master("spark://192.168.2.181:7077") \
        .appName("weak_scaling_6_core")\
        .config("spark.dynamicAllocation.enabled", True)\
        .config("spark.shuffle.service.enabled", True)\
        .config("spark.cores.max", 6)\
        .getOrCreate()

spark_context = spark_session.sparkContext

df = spark_session.read\
    .option("header", "true")\
    .csv(['hdfs://192.168.2.181:9000/user/ubuntu/songs_collection/*', 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection1/*', 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection2/*'
          , 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection3/*', 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection4/*', 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection5/*'])

df = df.withColumn('Duration', df['Duration'].cast("float"))
df = df.filter(df['Duration'] >= 240)
print("Amount of songs longer than 240 sec: "+str(df.count()))

# Release cores and stop application.
spark_context.stop()

# %%
from pyspark.sql import SparkSession

spark_session = SparkSession\
        .builder\
        .master("spark://192.168.2.181:7077") \
        .appName("weak_scaling_7_core")\
        .config("spark.dynamicAllocation.enabled", True)\
        .config("spark.shuffle.service.enabled", True)\
        .config("spark.cores.max", 7)\
        .getOrCreate()

spark_context = spark_session.sparkContext

df = spark_session.read\
    .option("header", "true")\
    .csv(['hdfs://192.168.2.181:9000/user/ubuntu/songs_collection/*', 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection1/*', 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection2/*'
          , 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection3/*', 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection4/*', 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection5/*'
          , 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection6/*'])

df = df.withColumn('Duration', df['Duration'].cast("float"))
df = df.filter(df['Duration'] >= 240)
print("Amount of songs longer than 240 sec: "+str(df.count()))

# Release cores and stop application.
spark_context.stop()

# %%
from pyspark.sql import SparkSession

spark_session = SparkSession\
        .builder\
        .master("spark://192.168.2.181:7077") \
        .appName("weak_scaling_8_core")\
        .config("spark.dynamicAllocation.enabled", True)\
        .config("spark.shuffle.service.enabled", True)\
        .config("spark.cores.max", 8)\
        .getOrCreate()

spark_context = spark_session.sparkContext

df = spark_session.read\
    .option("header", "true")\
    .csv(['hdfs://192.168.2.181:9000/user/ubuntu/songs_collection/*', 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection1/*', 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection2/*'
          , 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection3/*', 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection4/*', 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection5/*'
          , 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection6/*', 'hdfs://192.168.2.181:9000/user/ubuntu/songs_collection7/*'])

df = df.withColumn('Duration', df['Duration'].cast("float"))
df = df.filter(df['Duration'] >= 240)
print("Amount of songs longer than 240 sec: "+str(df.count()))

# Release cores and stop application.
spark_context.stop()
